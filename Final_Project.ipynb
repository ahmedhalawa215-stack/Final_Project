# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"D:\Artificial Intelligence Diploma Content\Data\data pre.csv")

# %%
df =pd.DataFrame(data)
df
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0       167647    Male   22                1          7.0                   1
# 1        17163    Male   42                1         28.0                   0
# 2        32023  Female   66                1         33.0                   0
# 3        87447  Female   22                1         33.0                   0
# 4       501933    Male   28                1         46.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 382149  164549    Male   24                1         15.0                   0
# 382150  247064    Male   27                1         28.0                   1
# 382151  165293    Male   45                1         28.0                   0
# 382152  383241  Female   28                1         28.0                   1
# 382153  401019  Female   29                1         18.0                   1
#
# ...

# %%
df.drop("id",axis=1,inplace=True)

# %%
df.describe()
# Out:
#                  Age  Driving_License    Region_Code  Previously_Insured  \
# count  382154.000000    382154.000000  382154.000000       382154.000000
# mean       38.545691         0.998108      26.406867            0.489182
# std        15.226897         0.043455      13.181241            0.499884
# min        20.000000         0.000000       0.000000            0.000000
# 25%        25.000000         1.000000      15.000000            0.000000
# 50%        36.000000         1.000000      28.000000            0.000000
# 75%        49.000000         1.000000      35.000000            1.000000
# max        85.000000         1.000000      52.000000            1.000000
#
#        Annual_Premium  Policy_Sales_Channel        Vintage       Response
# count   382154.000000         382154.000000  382154.000000  382154.000000
# mean     30711.271362            111.939812     154.189429       0.163811
# std      17061.595532             54.286511      83.735107       0.370104
# ...

# %%
df.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0    Male   22                1          7.0                   1    < 1 Year
# 1    Male   42                1         28.0                   0    1-2 Year
# 2  Female   66                1         33.0                   0    1-2 Year
# 3  Female   22                1         33.0                   0    < 1 Year
# 4    Male   28                1         46.0                   1    < 1 Year
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0             No          2630.0                 152.0       16         0
# 1            Yes         43327.0                  26.0      135         0
# 2            Yes         35841.0                 124.0      253         0
# 3             No         27645.0                 152.0       69         0
# 4             No         29023.0                 152.0      211         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382154 entries, 0 to 382153
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Gender                382154 non-null  object
#  1   Age                   382154 non-null  int64
#  2   Driving_License       382154 non-null  int64
#  3   Region_Code           382154 non-null  float64
#  4   Previously_Insured    382154 non-null  int64
#  5   Vehicle_Age           382154 non-null  object
#  6   Vehicle_Damage        382154 non-null  object
#  7   Annual_Premium        382154 non-null  float64
#  8   Policy_Sales_Channel  382154 non-null  float64
#  9   Vintage               382154 non-null  int64
#  10  Response              382154 non-null  int64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 32.1+ MB

# %%
cat_cols =df.select_dtypes(exclude=np.number).columns
